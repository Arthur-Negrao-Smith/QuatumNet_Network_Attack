# %% [markdown]
# # Guia da Camada de Transporte
# ### IMPORTANDO AS DEPENDÊNCIAS
# ##### O documento tem o objetivo de demostrar o funcionamento da camada de transporte, além de suas funções e ferramentas.

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger

# %% [markdown]
# ##### Instanciando a rede, e setando a topologia.

# %%
rede = Network()
rede.set_ready_topology("Grade", 3,3)
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# ##### Definindo os hosts alice e bob nos nós 1 e 2 respectivamente.

# %%
alice = rede.get_host(0)
bob = rede.get_host(8)

# %% [markdown]
# ##### Verificação da memória de Alice e Bob.

# %%
print('memoria de alice:',(alice.memory))
print('memoria de bob:',(bob.memory))
# Out:
# memoria de alice: [<quantumnet.objects.qubit.Qubit object at 0x0000021858922060>, <quantumnet.objects.qubit.Qubit object at 0x00000218589220F0>, <quantumnet.objects.qubit.Qubit object at 0x0000021858922090>, <quantumnet.objects.qubit.Qubit object at 0x0000021858922150>, <quantumnet.objects.qubit.Qubit object at 0x0000021858922180>, <quantumnet.objects.qubit.Qubit object at 0x0000021858922210>, <quantumnet.objects.qubit.Qubit object at 0x00000218589221B0>, <quantumnet.objects.qubit.Qubit object at 0x00000218589222A0>, <quantumnet.objects.qubit.Qubit object at 0x00000218589222D0>, <quantumnet.objects.qubit.Qubit object at 0x0000021858922300>]
# memoria de bob: [<quantumnet.objects.qubit.Qubit object at 0x0000021858923500>, <quantumnet.objects.qubit.Qubit object at 0x0000021858923590>, <quantumnet.objects.qubit.Qubit object at 0x00000218589235F0>, <quantumnet.objects.qubit.Qubit object at 0x0000021858923650>, <quantumnet.objects.qubit.Qubit object at 0x00000218589236B0>, <quantumnet.objects.qubit.Qubit object at 0x0000021858923710>, <quantumnet.objects.qubit.Qubit object at 0x0000021858923770>, <quantumnet.objects.qubit.Qubit object at 0x00000218589237D0>, <quantumnet.objects.qubit.Qubit object at 0x0000021858923830>, <quantumnet.objects.qubit.Qubit object at 0x0000021858923890>]

# %% [markdown]
# ##### A função a seguir é chamada para que seja realizada a requesição de uma rota para que haja a transmissão de n qubits necessários. Ela vai executar toda a camada de transporte.

# %%
rede.transportlayer.run_transport_layer(0,8,11)
# Out:
# 2024-11-17 15:11:07,020: Número insuficiente de qubits na memória de Alice (Host 0). Criando mais 1 qubits para completar os 11 necessários.
# 2024-11-17 15:11:07,023: Timeslot antes da criação do qubit: 1
# 2024-11-17 15:11:07,025: Qubit 90 adicionado à memória do Host 0.
# 2024-11-17 15:11:07,027: Qubit 90 criado com fidelidade inicial 0.0783071524918425 e adicionado à memória do Host 0.
# 2024-11-17 15:11:07,029: Qubit criado para Alice (Host 0) no timeslot: 2
# 2024-11-17 15:11:07,031: Tentativa 1 de transmissão de qubits entre 0 e 8.
# 2024-11-17 15:11:07,033: Timeslot 3: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,036: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,042: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.053182079607965914.
# 2024-11-17 15:11:07,044: Timeslot 4: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,046: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,048: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.010700181217169773.
# 2024-11-17 15:11:07,049: Timeslot 5: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,051: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,053: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.18620588528924778.
# 2024-11-17 15:11:07,059: Timeslot 6: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,061: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,064: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.16863237485656093.
# 2024-11-17 15:11:07,067: Timeslot 7: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,069: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,070: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.07127799807733456.
# 2024-11-17 15:11:07,073: Timeslot 8: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,074: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,077: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.18176415279502806.
# 2024-11-17 15:11:07,079: Timeslot 9: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,081: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,084: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.034622423605522375.
# 2024-11-17 15:11:07,088: Timeslot 10: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,090: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,092: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.0017196403053448164.
# 2024-11-17 15:11:07,094: Timeslot 11: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,096: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,097: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.043238875136655544.
# 2024-11-17 15:11:07,104: Timeslot 12: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,109: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,111: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.012218388797154445.
# 2024-11-17 15:11:07,113: Timeslot 13: Buscando rota válida entre 0 e 8.
# 2024-11-17 15:11:07,115: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-17 15:11:07,117: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.0062462830217525364.
# 2024-11-17 15:11:07,124: Transmissão e teletransporte de 11 qubits entre 0 e 8 concluídos com sucesso. Timeslot: 13
# True

# %% [markdown]
# ##### A função get_total_useds_qubits, será usada para mostrar quantos qubits foram usados na camada de Transporte.

# %%
rede.get_total_useds_qubits()
# Out:
# 2024-11-17 15:11:07,216: Qubits usados na camada PhysicalLayer: 1
# 2024-11-17 15:11:07,218: Qubits usados na camada LinkLayer: 0
# 2024-11-17 15:11:07,221: Qubits usados na camada TransportLayer: 11
# 2024-11-17 15:11:07,224: Qubits usados na camada ApplicationLayer: 0
# 12

# %% [markdown]
# ##### Essa função apresenta uma lista de métricas do transmissão dos qubits.

# %%
rede.transportlayer.get_teleported_qubits()
# Out:
# [{'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.07295209822766242,
#   'fidelity_route': 0.7290000000000001,
#   'F_final': 0.053182079607965914,
#   'timeslot': 3,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x21858922060>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.016308765763099788,
#   'fidelity_route': 0.6561000000000001,
#   'F_final': 0.010700181217169773,
#   'timeslot': 4,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x218589220f0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.31534130178199077,
#   'fidelity_route': 0.5904900000000002,
#   'F_final': 0.18620588528924778,
#   'timeslot': 5,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x21858922090>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.3173115639488878,
#   'fidelity_route': 0.5314410000000002,
#   'F_final': 0.16863237485656093,
#   'timeslot': 6,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x21858922150>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.14902458719120812,
#   'fidelity_route': 0.47829690000000014,
#   'F_final': 0.07127799807733456,
#   'timeslot': 7,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x21858922180>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.422248544308469,
#   'fidelity_route': 0.4304672100000001,
#   'F_final': 0.18176415279502806,
#   'timeslot': 8,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x21858922210>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.08936652703859027,
#   'fidelity_route': 0.38742048900000015,
#   'F_final': 0.034622423605522375,
#   'timeslot': 9,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x218589221b0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.004931880229966693,
#   'fidelity_route': 0.34867844010000015,
#   'F_final': 0.0017196403053448164,
#   'timeslot': 10,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x218589222a0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.13778653645033304,
#   'fidelity_route': 0.31381059609000017,
#   'F_final': 0.043238875136655544,
#   'timeslot': 11,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x218589222d0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.043261724497347005,
#   'fidelity_route': 0.28242953648100017,
#   'F_final': 0.012218388797154445,
#   'timeslot': 12,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x21858922300>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.024573614201575635,
#   'fidelity_route': 0.25418658283290013,
#   'F_final': 0.0062462830217525364,
#   'timeslot': 13,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x21858358590>}]

# %% [markdown]
# ##### No avg_fidelity_on_ltransportlayer, é realizada o cálculo da média da fidelidade dos ERPs criados na camada de Transporte.

# %%
rede.transportlayer.avg_fidelity_on_transportlayer()
# Out:
# 2024-11-17 15:11:07,350: Fidelidade do qubit utilizado de 0 para 8: 0.053182079607965914
# 2024-11-17 15:11:07,353: Fidelidade do qubit utilizado de 0 para 8: 0.010700181217169773
# 2024-11-17 15:11:07,355: Fidelidade do qubit utilizado de 0 para 8: 0.18620588528924778
# 2024-11-17 15:11:07,356: Fidelidade do qubit utilizado de 0 para 8: 0.16863237485656093
# 2024-11-17 15:11:07,358: Fidelidade do qubit utilizado de 0 para 8: 0.07127799807733456
# 2024-11-17 15:11:07,360: Fidelidade do qubit utilizado de 0 para 8: 0.18176415279502806
# 2024-11-17 15:11:07,362: Fidelidade do qubit utilizado de 0 para 8: 0.034622423605522375
# 2024-11-17 15:11:07,363: Fidelidade do qubit utilizado de 0 para 8: 0.0017196403053448164
# 2024-11-17 15:11:07,365: Fidelidade do qubit utilizado de 0 para 8: 0.043238875136655544
# 2024-11-17 15:11:07,366: Fidelidade do qubit utilizado de 0 para 8: 0.012218388797154445
# 2024-11-17 15:11:07,368: Fidelidade do qubit utilizado de 0 para 8: 0.0062462830217525364
# 2024-11-17 15:11:07,370: A fidelidade média de todos os qubits utilizados na camada de transporte é 0.0699825711554306
# 0.0699825711554306

# %% [markdown]
# ##### A função get_timeslot apresenta quantos timeslot se passaram durante a execução da camada.

# %%
rede.get_timeslot()
# Out:
# 13

# %% [markdown]
# ##### Por meio do display_all_qubits_timeslot, pode-se verificar em qual timeslot cada qubit foi criado.

# %%
rede.display_all_qubit_timeslots()
# Out:
# Qubit 0 foi criado no timeslot 0 na camada Physical Layer
# Qubit 1 foi criado no timeslot 0 na camada Physical Layer
# Qubit 2 foi criado no timeslot 0 na camada Physical Layer
# Qubit 3 foi criado no timeslot 0 na camada Physical Layer
# Qubit 4 foi criado no timeslot 0 na camada Physical Layer
# Qubit 5 foi criado no timeslot 0 na camada Physical Layer
# Qubit 6 foi criado no timeslot 0 na camada Physical Layer
# Qubit 7 foi criado no timeslot 0 na camada Physical Layer
# Qubit 8 foi criado no timeslot 0 na camada Physical Layer
# Qubit 9 foi criado no timeslot 0 na camada Physical Layer
# Qubit 10 foi criado no timeslot 0 na camada Physical Layer
# Qubit 11 foi criado no timeslot 0 na camada Physical Layer
# Qubit 12 foi criado no timeslot 0 na camada Physical Layer
# Qubit 13 foi criado no timeslot 0 na camada Physical Layer
# Qubit 14 foi criado no timeslot 0 na camada Physical Layer
# Qubit 15 foi criado no timeslot 0 na camada Physical Layer
# Qubit 16 foi criado no timeslot 0 na camada Physical Layer
# Qubit 17 foi criado no timeslot 0 na camada Physical Layer
# Qubit 18 foi criado no timeslot 0 na camada Physical Layer
# Qubit 19 foi criado no timeslot 0 na camada Physical Layer
# Qubit 20 foi criado no timeslot 0 na camada Physical Layer
# Qubit 21 foi criado no timeslot 0 na camada Physical Layer
# Qubit 22 foi criado no timeslot 0 na camada Physical Layer
# Qubit 23 foi criado no timeslot 0 na camada Physical Layer
# Qubit 24 foi criado no timeslot 0 na camada Physical Layer
# Qubit 25 foi criado no timeslot 0 na camada Physical Layer
# Qubit 26 foi criado no timeslot 0 na camada Physical Layer
# Qubit 27 foi criado no timeslot 0 na camada Physical Layer
# Qubit 28 foi criado no timeslot 0 na camada Physical Layer
# Qubit 29 foi criado no timeslot 0 na camada Physical Layer
# Qubit 30 foi criado no timeslot 0 na camada Physical Layer
# Qubit 31 foi criado no timeslot 0 na camada Physical Layer
# Qubit 32 foi criado no timeslot 0 na camada Physical Layer
# Qubit 33 foi criado no timeslot 0 na camada Physical Layer
# Qubit 34 foi criado no timeslot 0 na camada Physical Layer
# Qubit 35 foi criado no timeslot 0 na camada Physical Layer
# Qubit 36 foi criado no timeslot 0 na camada Physical Layer
# Qubit 37 foi criado no timeslot 0 na camada Physical Layer
# Qubit 38 foi criado no timeslot 0 na camada Physical Layer
# Qubit 39 foi criado no timeslot 0 na camada Physical Layer
# Qubit 40 foi criado no timeslot 0 na camada Physical Layer
# Qubit 41 foi criado no timeslot 0 na camada Physical Layer
# Qubit 42 foi criado no timeslot 0 na camada Physical Layer
# Qubit 43 foi criado no timeslot 0 na camada Physical Layer
# Qubit 44 foi criado no timeslot 0 na camada Physical Layer
# Qubit 45 foi criado no timeslot 0 na camada Physical Layer
# Qubit 46 foi criado no timeslot 0 na camada Physical Layer
# Qubit 47 foi criado no timeslot 0 na camada Physical Layer
# Qubit 48 foi criado no timeslot 0 na camada Physical Layer
# Qubit 49 foi criado no timeslot 0 na camada Physical Layer
# Qubit 50 foi criado no timeslot 0 na camada Physical Layer
# Qubit 51 foi criado no timeslot 0 na camada Physical Layer
# Qubit 52 foi criado no timeslot 0 na camada Physical Layer
# Qubit 53 foi criado no timeslot 0 na camada Physical Layer
# Qubit 54 foi criado no timeslot 0 na camada Physical Layer
# Qubit 55 foi criado no timeslot 0 na camada Physical Layer
# Qubit 56 foi criado no timeslot 0 na camada Physical Layer
# Qubit 57 foi criado no timeslot 0 na camada Physical Layer
# Qubit 58 foi criado no timeslot 0 na camada Physical Layer
# Qubit 59 foi criado no timeslot 0 na camada Physical Layer
# Qubit 60 foi criado no timeslot 0 na camada Physical Layer
# Qubit 61 foi criado no timeslot 0 na camada Physical Layer
# Qubit 62 foi criado no timeslot 0 na camada Physical Layer
# Qubit 63 foi criado no timeslot 0 na camada Physical Layer
# Qubit 64 foi criado no timeslot 0 na camada Physical Layer
# Qubit 65 foi criado no timeslot 0 na camada Physical Layer
# Qubit 66 foi criado no timeslot 0 na camada Physical Layer
# Qubit 67 foi criado no timeslot 0 na camada Physical Layer
# Qubit 68 foi criado no timeslot 0 na camada Physical Layer
# Qubit 69 foi criado no timeslot 0 na camada Physical Layer
# Qubit 70 foi criado no timeslot 0 na camada Physical Layer
# Qubit 71 foi criado no timeslot 0 na camada Physical Layer
# Qubit 72 foi criado no timeslot 0 na camada Physical Layer
# Qubit 73 foi criado no timeslot 0 na camada Physical Layer
# Qubit 74 foi criado no timeslot 0 na camada Physical Layer
# Qubit 75 foi criado no timeslot 0 na camada Physical Layer
# Qubit 76 foi criado no timeslot 0 na camada Physical Layer
# Qubit 77 foi criado no timeslot 0 na camada Physical Layer
# Qubit 78 foi criado no timeslot 0 na camada Physical Layer
# Qubit 79 foi criado no timeslot 0 na camada Physical Layer
# Qubit 80 foi criado no timeslot 0 na camada Physical Layer
# Qubit 81 foi criado no timeslot 0 na camada Physical Layer
# Qubit 82 foi criado no timeslot 0 na camada Physical Layer
# Qubit 83 foi criado no timeslot 0 na camada Physical Layer
# Qubit 84 foi criado no timeslot 0 na camada Physical Layer
# Qubit 85 foi criado no timeslot 0 na camada Physical Layer
# Qubit 86 foi criado no timeslot 0 na camada Physical Layer
# Qubit 87 foi criado no timeslot 0 na camada Physical Layer
# Qubit 88 foi criado no timeslot 0 na camada Physical Layer
# Qubit 89 foi criado no timeslot 0 na camada Physical Layer
# Qubit 90 foi criado no timeslot 2 na camada Physical Layer
