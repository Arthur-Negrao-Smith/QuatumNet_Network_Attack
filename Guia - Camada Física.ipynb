# %% [markdown]
# ## Guia da Camada Física
# ##### O documento tem o objetivo de demostrar o funcionamento da camada física, além de suas funções e ferramentas.

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger
import random

# %% [markdown]
# ##### Será definida a topologia de Grade na rede.

# %%
rede = Network()
rede.set_ready_topology("Grade", 3,3)
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# ##### Selecionando aleatoriamente uma aresta do grafo da rede e deseguinando quem será Alice e Bob.

# %%
arestas = list(rede.edges)
aresta_aleatorias = random.sample(arestas, 1)[0]
x,y = aresta_aleatorias

alice = rede.get_host(x)
bob = rede.get_host(y)

# %% [markdown]
# ##### Adicionando qubits aos hosts.

# %%
h1 = Qubit(1)
h2 = Qubit(2)

alice.add_qubit(h1)
bob.add_qubit(h2)
# Out:
# 2024-11-17 15:11:35,969: Qubit 1 adicionado à memória do Host 0.
# 2024-11-17 15:11:35,972: Qubit 2 adicionado à memória do Host 3.

# %% [markdown]
# ##### Acessando a memória dos Hosts.

# %%
print(alice.memory)
print(bob.memory)
# Out:
# [<quantumnet.objects.qubit.Qubit object at 0x000001EF8D1AFDA0>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D818A70>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D1AF590>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D1AF3E0>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D8728A0>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D872870>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D872840>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D8726C0>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D8728D0>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D872900>, <quantumnet.objects.qubit.Qubit object at 0x000001EF95902060>]
# [<quantumnet.objects.qubit.Qubit object at 0x000001EF8D872F00>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D872F60>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D872FC0>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D873020>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D873080>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D8730E0>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D873140>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D8731A0>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D873200>, <quantumnet.objects.qubit.Qubit object at 0x000001EF8D873260>, <quantumnet.objects.qubit.Qubit object at 0x000001EF95A27D40>]

# %% [markdown]
# ##### Obtendo o útimo qubit de um dos hosts.

# %%
qub1 = alice.get_last_qubit()

# %% [markdown]
# ##### Medindo a fidelidade entre dois qubits.

# %%
#Pode medir a fidelidade por meio dessa função
rede.physical.fidelity_measurement(h1,h2)
# Out:
# 2024-11-17 15:11:36,067: A fidelidade do qubit Qubit 1 with state 0 é 0.9387129371995464
# 2024-11-17 15:11:36,069: A fidelidade do qubit Qubit 2 with state 0 é 0.006058658578162235
# 2024-11-17 15:11:36,072: A fidelidade entre o qubit 0.9387129371995464 e o qubit 0.006058658578162235 é 0.005687341189395899
# 0.005687341189395899

# %% [markdown]
# ##### Medindo a fidelidade de um qubit.

# %%
#Pode se medir a fidelidade e acessar de somente um host
rede.physical.fidelity_measurement_only_one(h1)
# Out:
# 2024-11-17 15:11:36,124: A fidelidade do qubit Qubit 1 with state 0 é 0.9387129371995464
# 0.9387129371995464

# %% [markdown]
# ##### Protocolo de criação de entrelaçamento entre dois qubits.

# %%
rede.physical.entanglement_creation_heralding_protocol(alice,bob)
# Out:
# 2024-11-17 15:11:36,155: Timeslot 1: Par epr criado com fidelidade 0.0021681332535335293
# 2024-11-17 15:11:36,157: Timeslot 2: O protocolo de criação de emaranhamento foi bem sucedido, mas com fidelidade baixa.
# False

# %% [markdown]
# ##### Reavaliando a fidelidade de um qubit para comparar suas variações após a passagem de um timeslot.

# %%
#Pode se medir a fidelidade e acessar de somente um host
rede.physical.fidelity_measurement_only_one(h1)
# Out:
# 2024-11-17 15:11:36,192: A fidelidade do qubit Qubit 1 with state 0 é 0.9293258078275509
# 0.9293258078275509

# %% [markdown]
# ##### Realiza-se o primeiro protocolo, on demand, que através da fidelidade inicial e da probabilidade de sucesso do on demand determina o sucesso do ECHP.

# %%
rede.physical.echp_on_demand(2,5)
# Out:
# 2024-11-17 15:11:36,240: A fidelidade do qubit Qubit 29 with state 0 é 0.023554676743464
# 2024-11-17 15:11:36,242: A fidelidade do qubit Qubit 59 with state 0 é 0.4734648980026847
# 2024-11-17 15:11:36,245: Timeslot 3: A probabilidade de sucesso do ECHP falhou.
# False

# %% [markdown]
# ##### Realiza-se, então, o segundo protocolo, on replay, que através da fidelidade inicial e da probabilidade de sucesso do on replay determina o sucesso do ECHP.

# %%
rede.physical.echp_on_replay(2,5)
# Out:
# 2024-11-17 15:11:36,281: A fidelidade do qubit Qubit 28 with state 0 é 0.09148932483485271
# 2024-11-17 15:11:36,284: A fidelidade do qubit Qubit 58 with state 0 é 0.45947511073035396
# 2024-11-17 15:11:36,285: Timeslot 4: A probabilidade de sucesso do ECHP falhou.
# False

# %% [markdown]
# ##### A função get_total_useds_qubits, será usada para mostrar quantos qubits foram usados na camada Física.

# %%
rede.get_total_useds_qubits()
# Out:
# 2024-11-17 15:11:36,339: Qubits usados na camada PhysicalLayer: 6
# 2024-11-17 15:11:36,341: Qubits usados na camada LinkLayer: 0
# 2024-11-17 15:11:36,342: Qubits usados na camada TransportLayer: 0
# 2024-11-17 15:11:36,344: Qubits usados na camada ApplicationLayer: 0
# 6

# %% [markdown]
# ##### Nesta função, get_total_used_erps, será calculado a quantidade de pares EPRs usados na camada Física.

# %%
rede.get_total_useds_eprs()
# Out:
# 2024-11-17 15:11:36,411: Eprs usados na camada PhysicalLayer: 1
# 2024-11-17 15:11:36,413: Eprs usados na camada LinkLayer: 0
# 2024-11-17 15:11:36,415: Eprs usados na camada NetworkLayer: 0
# 1

# %% [markdown]
# ##### Acessando o canal que mostra as probablidades e os pares eprs.

# %%
rede.edges[2,5]
# Out:
# {'prob_on_demand_epr_create': 0.551735014674803,
#  'prob_replay_epr_create': 0.39309380006114475,
#  'eprs': [<quantumnet.objects.epr.Epr at 0x1ef8d8a8aa0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8b00>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8b60>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8bc0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8c20>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8c80>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8ce0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8d40>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8da0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8e00>]}

# %% [markdown]
# ##### Acessando o dicionario que contém os pares eprs alocados.

# %%
rede.get_eprs()
# Out:
# {(0, 3): [<quantumnet.objects.epr.Epr at 0x1ef8d8a8050>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d1c9100>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8080>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a80b0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a80e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8110>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8140>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8170>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a81a0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a81d0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d458440>],
#  (0, 1): [<quantumnet.objects.epr.Epr at 0x1ef8d8a8200>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8230>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8260>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8290>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a82c0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a82f0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8320>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8350>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8380>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a83b0>],
#  (1, 4): [<quantumnet.objects.epr.Epr at 0x1ef8d8a83e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8410>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8440>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8470>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a84a0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8500>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8560>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a85c0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8620>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8680>],
#  (1, 2): [<quantumnet.objects.epr.Epr at 0x1ef8d8a86e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8740>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a87a0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8800>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8860>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a88c0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8920>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8980>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a89e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8a40>],
#  (2, 5): [<quantumnet.objects.epr.Epr at 0x1ef8d8a8aa0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8b00>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8b60>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8bc0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8c20>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8c80>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8ce0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8d40>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8da0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8e00>],
#  (3, 6): [<quantumnet.objects.epr.Epr at 0x1ef8d8a8e60>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8ec0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8f20>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8f80>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a8fe0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9040>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a90a0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9100>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9160>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a91c0>],
#  (3, 4): [<quantumnet.objects.epr.Epr at 0x1ef8d8a9220>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9280>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a92e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9340>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a93a0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9400>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9460>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a94c0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9520>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9580>],
#  (4, 7): [<quantumnet.objects.epr.Epr at 0x1ef8d8a95e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9640>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a96a0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9700>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9760>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a97c0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9820>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9880>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a98e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9940>],
#  (4, 5): [<quantumnet.objects.epr.Epr at 0x1ef8d8a99a0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9a00>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9a60>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9ac0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9b20>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9b80>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9be0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9c40>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9ca0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9d00>],
#  (5, 8): [<quantumnet.objects.epr.Epr at 0x1ef8d8a9d60>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9dc0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9e20>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9e80>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9ee0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9f40>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8a9fa0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa000>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa060>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa0c0>],
#  (6, 7): [<quantumnet.objects.epr.Epr at 0x1ef8d8aa120>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa180>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa1e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa240>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa2a0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa300>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa360>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa3c0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa420>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa480>],
#  (7, 8): [<quantumnet.objects.epr.Epr at 0x1ef8d8aa4e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa540>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa5a0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa600>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa660>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa6c0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa720>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa780>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa7e0>,
#   <quantumnet.objects.epr.Epr at 0x1ef8d8aa840>]}

# %% [markdown]
# ##### A função get_timeslot apresenta quantos timeslot se passaram durante a execução da camada.

# %%
rede.get_timeslot()
# Out:
# 4

# %%
rede.display_all_qubit_timeslots()
# Out:
# Qubit 0 foi criado no timeslot 0 na camada Physical Layer
# Qubit 1 foi criado no timeslot 0 na camada Physical Layer
# Qubit 2 foi criado no timeslot 0 na camada Physical Layer
# Qubit 3 foi criado no timeslot 0 na camada Physical Layer
# Qubit 4 foi criado no timeslot 0 na camada Physical Layer
# Qubit 5 foi criado no timeslot 0 na camada Physical Layer
# Qubit 6 foi criado no timeslot 0 na camada Physical Layer
# Qubit 7 foi criado no timeslot 0 na camada Physical Layer
# Qubit 8 foi criado no timeslot 0 na camada Physical Layer
# Qubit 9 foi criado no timeslot 0 na camada Physical Layer
# Qubit 10 foi criado no timeslot 0 na camada Physical Layer
# Qubit 11 foi criado no timeslot 0 na camada Physical Layer
# Qubit 12 foi criado no timeslot 0 na camada Physical Layer
# Qubit 13 foi criado no timeslot 0 na camada Physical Layer
# Qubit 14 foi criado no timeslot 0 na camada Physical Layer
# Qubit 15 foi criado no timeslot 0 na camada Physical Layer
# Qubit 16 foi criado no timeslot 0 na camada Physical Layer
# Qubit 17 foi criado no timeslot 0 na camada Physical Layer
# Qubit 18 foi criado no timeslot 0 na camada Physical Layer
# Qubit 19 foi criado no timeslot 0 na camada Physical Layer
# Qubit 20 foi criado no timeslot 0 na camada Physical Layer
# Qubit 21 foi criado no timeslot 0 na camada Physical Layer
# Qubit 22 foi criado no timeslot 0 na camada Physical Layer
# Qubit 23 foi criado no timeslot 0 na camada Physical Layer
# Qubit 24 foi criado no timeslot 0 na camada Physical Layer
# Qubit 25 foi criado no timeslot 0 na camada Physical Layer
# Qubit 26 foi criado no timeslot 0 na camada Physical Layer
# Qubit 27 foi criado no timeslot 0 na camada Physical Layer
# Qubit 28 foi criado no timeslot 0 na camada Physical Layer
# Qubit 29 foi criado no timeslot 0 na camada Physical Layer
# Qubit 30 foi criado no timeslot 0 na camada Physical Layer
# Qubit 31 foi criado no timeslot 0 na camada Physical Layer
# Qubit 32 foi criado no timeslot 0 na camada Physical Layer
# Qubit 33 foi criado no timeslot 0 na camada Physical Layer
# Qubit 34 foi criado no timeslot 0 na camada Physical Layer
# Qubit 35 foi criado no timeslot 0 na camada Physical Layer
# Qubit 36 foi criado no timeslot 0 na camada Physical Layer
# Qubit 37 foi criado no timeslot 0 na camada Physical Layer
# Qubit 38 foi criado no timeslot 0 na camada Physical Layer
# Qubit 39 foi criado no timeslot 0 na camada Physical Layer
# Qubit 40 foi criado no timeslot 0 na camada Physical Layer
# Qubit 41 foi criado no timeslot 0 na camada Physical Layer
# Qubit 42 foi criado no timeslot 0 na camada Physical Layer
# Qubit 43 foi criado no timeslot 0 na camada Physical Layer
# Qubit 44 foi criado no timeslot 0 na camada Physical Layer
# Qubit 45 foi criado no timeslot 0 na camada Physical Layer
# Qubit 46 foi criado no timeslot 0 na camada Physical Layer
# Qubit 47 foi criado no timeslot 0 na camada Physical Layer
# Qubit 48 foi criado no timeslot 0 na camada Physical Layer
# Qubit 49 foi criado no timeslot 0 na camada Physical Layer
# Qubit 50 foi criado no timeslot 0 na camada Physical Layer
# Qubit 51 foi criado no timeslot 0 na camada Physical Layer
# Qubit 52 foi criado no timeslot 0 na camada Physical Layer
# Qubit 53 foi criado no timeslot 0 na camada Physical Layer
# Qubit 54 foi criado no timeslot 0 na camada Physical Layer
# Qubit 55 foi criado no timeslot 0 na camada Physical Layer
# Qubit 56 foi criado no timeslot 0 na camada Physical Layer
# Qubit 57 foi criado no timeslot 0 na camada Physical Layer
# Qubit 58 foi criado no timeslot 0 na camada Physical Layer
# Qubit 59 foi criado no timeslot 0 na camada Physical Layer
# Qubit 60 foi criado no timeslot 0 na camada Physical Layer
# Qubit 61 foi criado no timeslot 0 na camada Physical Layer
# Qubit 62 foi criado no timeslot 0 na camada Physical Layer
# Qubit 63 foi criado no timeslot 0 na camada Physical Layer
# Qubit 64 foi criado no timeslot 0 na camada Physical Layer
# Qubit 65 foi criado no timeslot 0 na camada Physical Layer
# Qubit 66 foi criado no timeslot 0 na camada Physical Layer
# Qubit 67 foi criado no timeslot 0 na camada Physical Layer
# Qubit 68 foi criado no timeslot 0 na camada Physical Layer
# Qubit 69 foi criado no timeslot 0 na camada Physical Layer
# Qubit 70 foi criado no timeslot 0 na camada Physical Layer
# Qubit 71 foi criado no timeslot 0 na camada Physical Layer
# Qubit 72 foi criado no timeslot 0 na camada Physical Layer
# Qubit 73 foi criado no timeslot 0 na camada Physical Layer
# Qubit 74 foi criado no timeslot 0 na camada Physical Layer
# Qubit 75 foi criado no timeslot 0 na camada Physical Layer
# Qubit 76 foi criado no timeslot 0 na camada Physical Layer
# Qubit 77 foi criado no timeslot 0 na camada Physical Layer
# Qubit 78 foi criado no timeslot 0 na camada Physical Layer
# Qubit 79 foi criado no timeslot 0 na camada Physical Layer
# Qubit 80 foi criado no timeslot 0 na camada Physical Layer
# Qubit 81 foi criado no timeslot 0 na camada Physical Layer
# Qubit 82 foi criado no timeslot 0 na camada Physical Layer
# Qubit 83 foi criado no timeslot 0 na camada Physical Layer
# Qubit 84 foi criado no timeslot 0 na camada Physical Layer
# Qubit 85 foi criado no timeslot 0 na camada Physical Layer
# Qubit 86 foi criado no timeslot 0 na camada Physical Layer
# Qubit 87 foi criado no timeslot 0 na camada Physical Layer
# Qubit 88 foi criado no timeslot 0 na camada Physical Layer
# Qubit 89 foi criado no timeslot 0 na camada Physical Layer
