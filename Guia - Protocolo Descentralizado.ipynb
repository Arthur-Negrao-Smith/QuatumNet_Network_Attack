# %% [markdown]
# ## Protocolo Descentralizado
#
# No protocolo descentralizado, o preenchimento das tabelas de repasse dos ``Hosts`` é feito sem o uso de um controlador.

# %%
from quantumnet.components import Network, Host
import networkx as nx

# %% [markdown]
# Criando uma versão extendida do Host. Essa versão diferencia-se pelo método adicional ``exchange_routes()`` que realiza a troca de rotas de forma descentralizada.

# %%
class DescHost(Host):
    def __init__(self, host_id):
        super().__init__(host_id)
        #self.host_id = host_id
    
    def exchange_routes(self, neighbor):
        updated = False
        neighbor_routing_table = neighbor.routing_table

        print(f"\nNode {self.host_id} exchanging routes with Neighbor {neighbor.host_id}")
        print(f"Current Routing Table for Node {self.host_id}: {self.routing_table}")
        print(f"Neighbor {neighbor.host_id} Routing Table: {neighbor_routing_table}")

        for dest, neighbor_path in neighbor_routing_table.items():
            # If we don't know the destination or found a shorter path through the neighbor
            if dest not in self.routing_table or len(neighbor_path) + 1 < len(self.routing_table[dest]):
                old_route = self.routing_table.get(dest, "None")
                self.routing_table[dest] = [self.host_id] + neighbor_path  # Prepend own ID to the path
                updated = True
                print(f"Node {self.host_id} updated route to {dest}: {old_route} -> {self.routing_table[dest]}")

        return updated

# %% [markdown]
# A função a seguir somente cria uma topologia pronta, é um método da classe ``Network`` também.

# %%
def set_ready_topology(rede, topology_name: str, *args: int) -> str:
        """
        Cria um grafo com uma das topologias prontas para serem utilizadas. 
        São elas: Grade, Linha, Anel. Os nós são numerados de 0 a n-1, onde n é o número de nós.

        Args: 
            topology_name (str): Nome da topologia a ser utilizada.
            **args (int): Argumentos para a topologia. Geralmente, o número de hosts.
        
        """
        # Nomeia a topologia da rede
        rede._topology = topology_name
    
        # Cria o grafo da topologia escolhida
        if topology_name == 'Grade':
            if len(args) != 2:
                raise Exception('Para a topologia Grade, são necessários dois argumentos.')
            rede._graph = nx.grid_2d_graph(*args)
        elif topology_name == 'Linha':
            if len(args) != 1:
                raise Exception('Para a topologia Linha, é necessário um argumento.')
            rede._graph = nx.path_graph(*args)
        elif topology_name == 'Anel':
            if len(args) != 1:
                raise Exception('Para a topologia Anel, é necessário um argumento.')
            rede._graph = nx.cycle_graph(*args)

        # Converte os labels dos nós para inteiros
        rede._graph = nx.convert_node_labels_to_integers(rede._graph)

        # Cria os hosts e adiciona ao dicionário de hosts
        for node in rede._graph.nodes():
            rede._hosts[node] = DescHost(node)
        rede.start_hosts()
        rede.start_channels()
        rede.start_eprs()

# %% [markdown]
# Protocolo de troca de rotas descentralizado para os nós da rede.

# %%
def qbgp(rede, max_iterations=20):
    """
    Run the Quantum BGP algorithm on the given nodes.

    Args:
        nodes (list): List of nodes in the network.
        max_iterations (int): Maximum number of iterations to run the algorithm.
    """
    iteration = 0
    updated = True

    while updated and iteration < max_iterations:
        print(f"\n===================== Iteration {iteration+1} =====================")
        updated = False
        # Go through each node and let it exchange routes with its neighbors
        for host_id, host in rede.hosts.items():
            for neighbor_id in rede.graph.neighbors(host_id):
                neighbor_node = rede.get_host(neighbor_id)
                if host.exchange_routes(neighbor_node):
                    updated = True  # If any node updates its table, we continue the process
        iteration += 1

# %% [markdown]
# A rede é iniciada:

# %%
rede = Network()
set_ready_topology(rede, "Grade", 3, 3)
rede.draw()
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# A tabela de roteamento dos nós contém apenas o caminho para os próprios nós. Ou seja, não contém nenhuma informação sobre as rotas ainda.

# %% [markdown]
# Cada nó da rede se comunica com os outros nós da rede trocando informações. A cada iteração, os nós trocam informações sobre seus caminhos com seus vizinhos. Se um nó encontra um caminho mais curto para algum destino através de um vizinho, ele atualiza sua tabela de roteamento. Isso continua até que nenhuma tabela seja mais atualizada ou o número máximo de iterações seja atingido.

# %%
qbgp(rede)
# Out:
# ===================== Iteration 1 =====================
#
# Node 0 exchanging routes with Neighbor 3
# Current Routing Table for Node 0: {0: [0]}
# Neighbor 3 Routing Table: {3: [3]}
# Node 0 updated route to 3: None -> [0, 3]
#
# Node 0 exchanging routes with Neighbor 1
# Current Routing Table for Node 0: {0: [0], 3: [0, 3]}
# Neighbor 1 Routing Table: {1: [1]}
# Node 0 updated route to 1: None -> [0, 1]
#
# Node 1 exchanging routes with Neighbor 0
# Current Routing Table for Node 1: {1: [1]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1]}
# Node 1 updated route to 0: None -> [1, 0]
# Node 1 updated route to 3: None -> [1, 0, 3]
#
# Node 1 exchanging routes with Neighbor 4
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3]}
# Neighbor 4 Routing Table: {4: [4]}
# Node 1 updated route to 4: None -> [1, 4]
#
# Node 1 exchanging routes with Neighbor 2
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4]}
# Neighbor 2 Routing Table: {2: [2]}
# Node 1 updated route to 2: None -> [1, 2]
#
# Node 2 exchanging routes with Neighbor 1
# Current Routing Table for Node 2: {2: [2]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2]}
# Node 2 updated route to 1: None -> [2, 1]
# Node 2 updated route to 0: None -> [2, 1, 0]
# Node 2 updated route to 3: None -> [2, 1, 0, 3]
# Node 2 updated route to 4: None -> [2, 1, 4]
#
# Node 2 exchanging routes with Neighbor 5
# Current Routing Table for Node 2: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4]}
# Neighbor 5 Routing Table: {5: [5]}
# Node 2 updated route to 5: None -> [2, 5]
#
# Node 3 exchanging routes with Neighbor 0
# Current Routing Table for Node 3: {3: [3]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1]}
# Node 3 updated route to 0: None -> [3, 0]
# Node 3 updated route to 1: None -> [3, 0, 1]
#
# Node 3 exchanging routes with Neighbor 6
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1]}
# Neighbor 6 Routing Table: {6: [6]}
# Node 3 updated route to 6: None -> [3, 6]
#
# Node 3 exchanging routes with Neighbor 4
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6]}
# Neighbor 4 Routing Table: {4: [4]}
# Node 3 updated route to 4: None -> [3, 4]
#
# Node 4 exchanging routes with Neighbor 1
# Current Routing Table for Node 4: {4: [4]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2]}
# Node 4 updated route to 1: None -> [4, 1]
# Node 4 updated route to 0: None -> [4, 1, 0]
# Node 4 updated route to 3: None -> [4, 1, 0, 3]
# Node 4 updated route to 2: None -> [4, 1, 2]
#
# Node 4 exchanging routes with Neighbor 3
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 1, 0, 3], 2: [4, 1, 2]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4]}
# Node 4 updated route to 3: [4, 1, 0, 3] -> [4, 3]
# Node 4 updated route to 6: None -> [4, 3, 6]
#
# Node 4 exchanging routes with Neighbor 7
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6]}
# Neighbor 7 Routing Table: {7: [7]}
# Node 4 updated route to 7: None -> [4, 7]
#
# Node 4 exchanging routes with Neighbor 5
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7]}
# Neighbor 5 Routing Table: {5: [5]}
# Node 4 updated route to 5: None -> [4, 5]
#
# Node 5 exchanging routes with Neighbor 2
# Current Routing Table for Node 5: {5: [5]}
# Neighbor 2 Routing Table: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5]}
# Node 5 updated route to 2: None -> [5, 2]
# Node 5 updated route to 1: None -> [5, 2, 1]
# Node 5 updated route to 0: None -> [5, 2, 1, 0]
# Node 5 updated route to 3: None -> [5, 2, 1, 0, 3]
# Node 5 updated route to 4: None -> [5, 2, 1, 4]
#
# Node 5 exchanging routes with Neighbor 4
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 2, 1, 0, 3], 4: [5, 2, 1, 4]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5]}
# Node 5 updated route to 4: [5, 2, 1, 4] -> [5, 4]
# Node 5 updated route to 3: [5, 2, 1, 0, 3] -> [5, 4, 3]
# Node 5 updated route to 6: None -> [5, 4, 3, 6]
# Node 5 updated route to 7: None -> [5, 4, 7]
#
# Node 5 exchanging routes with Neighbor 8
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7]}
# Neighbor 8 Routing Table: {8: [8]}
# Node 5 updated route to 8: None -> [5, 8]
#
# Node 6 exchanging routes with Neighbor 3
# Current Routing Table for Node 6: {6: [6]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4]}
# Node 6 updated route to 3: None -> [6, 3]
# Node 6 updated route to 0: None -> [6, 3, 0]
# Node 6 updated route to 1: None -> [6, 3, 0, 1]
# Node 6 updated route to 4: None -> [6, 3, 4]
#
# Node 6 exchanging routes with Neighbor 7
# Current Routing Table for Node 6: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4]}
# Neighbor 7 Routing Table: {7: [7]}
# Node 6 updated route to 7: None -> [6, 7]
#
# Node 7 exchanging routes with Neighbor 4
# Current Routing Table for Node 7: {7: [7]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5]}
# Node 7 updated route to 4: None -> [7, 4]
# Node 7 updated route to 1: None -> [7, 4, 1]
# Node 7 updated route to 0: None -> [7, 4, 1, 0]
# Node 7 updated route to 3: None -> [7, 4, 3]
# Node 7 updated route to 2: None -> [7, 4, 1, 2]
# Node 7 updated route to 6: None -> [7, 4, 3, 6]
# Node 7 updated route to 5: None -> [7, 4, 5]
#
# Node 7 exchanging routes with Neighbor 6
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 4, 3, 6], 5: [7, 4, 5]}
# Neighbor 6 Routing Table: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7]}
# Node 7 updated route to 6: [7, 4, 3, 6] -> [7, 6]
#
# Node 7 exchanging routes with Neighbor 8
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5]}
# Neighbor 8 Routing Table: {8: [8]}
# Node 7 updated route to 8: None -> [7, 8]
#
# Node 8 exchanging routes with Neighbor 5
# Current Routing Table for Node 8: {8: [8]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Node 8 updated route to 5: None -> [8, 5]
# Node 8 updated route to 2: None -> [8, 5, 2]
# Node 8 updated route to 1: None -> [8, 5, 2, 1]
# Node 8 updated route to 0: None -> [8, 5, 2, 1, 0]
# Node 8 updated route to 3: None -> [8, 5, 4, 3]
# Node 8 updated route to 4: None -> [8, 5, 4]
# Node 8 updated route to 6: None -> [8, 5, 4, 3, 6]
# Node 8 updated route to 7: None -> [8, 5, 4, 7]
#
# Node 8 exchanging routes with Neighbor 7
# Current Routing Table for Node 8: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 5, 4, 3, 6], 7: [8, 5, 4, 7]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Node 8 updated route to 7: [8, 5, 4, 7] -> [8, 7]
# Node 8 updated route to 6: [8, 5, 4, 3, 6] -> [8, 7, 6]
#
# ===================== Iteration 2 =====================
#
# Node 0 exchanging routes with Neighbor 3
# Current Routing Table for Node 0: {0: [0], 3: [0, 3], 1: [0, 1]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4]}
# Node 0 updated route to 6: None -> [0, 3, 6]
# Node 0 updated route to 4: None -> [0, 3, 4]
#
# Node 0 exchanging routes with Neighbor 1
# Current Routing Table for Node 0: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2]}
# Node 0 updated route to 2: None -> [0, 1, 2]
#
# Node 1 exchanging routes with Neighbor 0
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2]}
# Node 1 updated route to 6: None -> [1, 0, 3, 6]
#
# Node 1 exchanging routes with Neighbor 4
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5]}
# Node 1 updated route to 7: None -> [1, 4, 7]
# Node 1 updated route to 5: None -> [1, 4, 5]
#
# Node 1 exchanging routes with Neighbor 2
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5]}
# Neighbor 2 Routing Table: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5]}
#
# Node 2 exchanging routes with Neighbor 1
# Current Routing Table for Node 2: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5]}
# Node 2 updated route to 6: None -> [2, 1, 0, 3, 6]
# Node 2 updated route to 7: None -> [2, 1, 4, 7]
#
# Node 2 exchanging routes with Neighbor 5
# Current Routing Table for Node 2: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Node 2 updated route to 8: None -> [2, 5, 8]
#
# Node 3 exchanging routes with Neighbor 0
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2]}
# Node 3 updated route to 2: None -> [3, 0, 1, 2]
#
# Node 3 exchanging routes with Neighbor 6
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2]}
# Neighbor 6 Routing Table: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7]}
# Node 3 updated route to 7: None -> [3, 6, 7]
#
# Node 3 exchanging routes with Neighbor 4
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5]}
# Node 3 updated route to 5: None -> [3, 4, 5]
#
# Node 4 exchanging routes with Neighbor 1
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5]}
#
# Node 4 exchanging routes with Neighbor 3
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5]}
#
# Node 4 exchanging routes with Neighbor 7
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Node 4 updated route to 8: None -> [4, 7, 8]
#
# Node 4 exchanging routes with Neighbor 5
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 5 exchanging routes with Neighbor 2
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 2 Routing Table: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
#
# Node 5 exchanging routes with Neighbor 4
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 5 exchanging routes with Neighbor 8
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 8 Routing Table: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
#
# Node 6 exchanging routes with Neighbor 3
# Current Routing Table for Node 6: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5]}
# Node 6 updated route to 2: None -> [6, 3, 0, 1, 2]
# Node 6 updated route to 5: None -> [6, 3, 4, 5]
#
# Node 6 exchanging routes with Neighbor 7
# Current Routing Table for Node 6: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Node 6 updated route to 8: None -> [6, 7, 8]
#
# Node 7 exchanging routes with Neighbor 4
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 7 exchanging routes with Neighbor 6
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 6 Routing Table: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
#
# Node 7 exchanging routes with Neighbor 8
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 8 Routing Table: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
#
# Node 8 exchanging routes with Neighbor 5
# Current Routing Table for Node 8: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 8 exchanging routes with Neighbor 7
# Current Routing Table for Node 8: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
#
# ===================== Iteration 3 =====================
#
# Node 0 exchanging routes with Neighbor 3
# Current Routing Table for Node 0: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5]}
# Node 0 updated route to 7: None -> [0, 3, 6, 7]
# Node 0 updated route to 5: None -> [0, 3, 4, 5]
#
# Node 0 exchanging routes with Neighbor 1
# Current Routing Table for Node 0: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5]}
#
# Node 1 exchanging routes with Neighbor 0
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5]}
#
# Node 1 exchanging routes with Neighbor 4
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Node 1 updated route to 8: None -> [1, 4, 7, 8]
#
# Node 1 exchanging routes with Neighbor 2
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
# Neighbor 2 Routing Table: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
#
# Node 2 exchanging routes with Neighbor 1
# Current Routing Table for Node 2: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
#
# Node 2 exchanging routes with Neighbor 5
# Current Routing Table for Node 2: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 3 exchanging routes with Neighbor 0
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5]}
#
# Node 3 exchanging routes with Neighbor 6
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5]}
# Neighbor 6 Routing Table: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
# Node 3 updated route to 8: None -> [3, 6, 7, 8]
#
# Node 3 exchanging routes with Neighbor 4
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 4 exchanging routes with Neighbor 1
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
#
# Node 4 exchanging routes with Neighbor 3
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
#
# Node 4 exchanging routes with Neighbor 7
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
#
# Node 4 exchanging routes with Neighbor 5
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 5 exchanging routes with Neighbor 2
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 2 Routing Table: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
#
# Node 5 exchanging routes with Neighbor 4
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 5 exchanging routes with Neighbor 8
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 8 Routing Table: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
#
# Node 6 exchanging routes with Neighbor 3
# Current Routing Table for Node 6: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
#
# Node 6 exchanging routes with Neighbor 7
# Current Routing Table for Node 6: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
#
# Node 7 exchanging routes with Neighbor 4
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 7 exchanging routes with Neighbor 6
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 6 Routing Table: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
#
# Node 7 exchanging routes with Neighbor 8
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 8 Routing Table: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
#
# Node 8 exchanging routes with Neighbor 5
# Current Routing Table for Node 8: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 8 exchanging routes with Neighbor 7
# Current Routing Table for Node 8: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
#
# ===================== Iteration 4 =====================
#
# Node 0 exchanging routes with Neighbor 3
# Current Routing Table for Node 0: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
# Node 0 updated route to 8: None -> [0, 3, 6, 7, 8]
#
# Node 0 exchanging routes with Neighbor 1
# Current Routing Table for Node 0: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5], 8: [0, 3, 6, 7, 8]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
#
# Node 1 exchanging routes with Neighbor 0
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5], 8: [0, 3, 6, 7, 8]}
#
# Node 1 exchanging routes with Neighbor 4
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 1 exchanging routes with Neighbor 2
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
# Neighbor 2 Routing Table: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
#
# Node 2 exchanging routes with Neighbor 1
# Current Routing Table for Node 2: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
#
# Node 2 exchanging routes with Neighbor 5
# Current Routing Table for Node 2: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 3 exchanging routes with Neighbor 0
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5], 8: [0, 3, 6, 7, 8]}
#
# Node 3 exchanging routes with Neighbor 6
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
# Neighbor 6 Routing Table: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
#
# Node 3 exchanging routes with Neighbor 4
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 4 exchanging routes with Neighbor 1
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
#
# Node 4 exchanging routes with Neighbor 3
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
#
# Node 4 exchanging routes with Neighbor 7
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
#
# Node 4 exchanging routes with Neighbor 5
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 5 exchanging routes with Neighbor 2
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 2 Routing Table: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
#
# Node 5 exchanging routes with Neighbor 4
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 5 exchanging routes with Neighbor 8
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 8 Routing Table: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
#
# Node 6 exchanging routes with Neighbor 3
# Current Routing Table for Node 6: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
#
# Node 6 exchanging routes with Neighbor 7
# Current Routing Table for Node 6: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
#
# Node 7 exchanging routes with Neighbor 4
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 7 exchanging routes with Neighbor 6
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 6 Routing Table: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
#
# Node 7 exchanging routes with Neighbor 8
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 8 Routing Table: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
#
# Node 8 exchanging routes with Neighbor 5
# Current Routing Table for Node 8: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 8 exchanging routes with Neighbor 7
# Current Routing Table for Node 8: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
#
# ===================== Iteration 5 =====================
#
# Node 0 exchanging routes with Neighbor 3
# Current Routing Table for Node 0: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5], 8: [0, 3, 6, 7, 8]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
#
# Node 0 exchanging routes with Neighbor 1
# Current Routing Table for Node 0: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5], 8: [0, 3, 6, 7, 8]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
#
# Node 1 exchanging routes with Neighbor 0
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5], 8: [0, 3, 6, 7, 8]}
#
# Node 1 exchanging routes with Neighbor 4
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 1 exchanging routes with Neighbor 2
# Current Routing Table for Node 1: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
# Neighbor 2 Routing Table: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
#
# Node 2 exchanging routes with Neighbor 1
# Current Routing Table for Node 2: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
#
# Node 2 exchanging routes with Neighbor 5
# Current Routing Table for Node 2: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 3 exchanging routes with Neighbor 0
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
# Neighbor 0 Routing Table: {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5], 8: [0, 3, 6, 7, 8]}
#
# Node 3 exchanging routes with Neighbor 6
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
# Neighbor 6 Routing Table: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
#
# Node 3 exchanging routes with Neighbor 4
# Current Routing Table for Node 3: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 4 exchanging routes with Neighbor 1
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 1 Routing Table: {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}
#
# Node 4 exchanging routes with Neighbor 3
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
#
# Node 4 exchanging routes with Neighbor 7
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
#
# Node 4 exchanging routes with Neighbor 5
# Current Routing Table for Node 4: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 5 exchanging routes with Neighbor 2
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 2 Routing Table: {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}
#
# Node 5 exchanging routes with Neighbor 4
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 5 exchanging routes with Neighbor 8
# Current Routing Table for Node 5: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
# Neighbor 8 Routing Table: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
#
# Node 6 exchanging routes with Neighbor 3
# Current Routing Table for Node 6: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
# Neighbor 3 Routing Table: {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}
#
# Node 6 exchanging routes with Neighbor 7
# Current Routing Table for Node 6: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
#
# Node 7 exchanging routes with Neighbor 4
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 4 Routing Table: {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}
#
# Node 7 exchanging routes with Neighbor 6
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 6 Routing Table: {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}
#
# Node 7 exchanging routes with Neighbor 8
# Current Routing Table for Node 7: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}
# Neighbor 8 Routing Table: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
#
# Node 8 exchanging routes with Neighbor 5
# Current Routing Table for Node 8: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
# Neighbor 5 Routing Table: {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}
#
# Node 8 exchanging routes with Neighbor 7
# Current Routing Table for Node 8: {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}
# Neighbor 7 Routing Table: {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}

# %%
for host_id in rede.hosts:
    print(rede.get_host(host_id).info())
# Out:
# {'host_id': 0, 'memory': 10, 'routing_table': {0: [0], 3: [0, 3], 1: [0, 1], 6: [0, 3, 6], 4: [0, 3, 4], 2: [0, 1, 2], 7: [0, 3, 6, 7], 5: [0, 3, 4, 5], 8: [0, 3, 6, 7, 8]}}
# {'host_id': 1, 'memory': 10, 'routing_table': {1: [1], 0: [1, 0], 3: [1, 0, 3], 4: [1, 4], 2: [1, 2], 6: [1, 0, 3, 6], 7: [1, 4, 7], 5: [1, 4, 5], 8: [1, 4, 7, 8]}}
# {'host_id': 2, 'memory': 10, 'routing_table': {2: [2], 1: [2, 1], 0: [2, 1, 0], 3: [2, 1, 0, 3], 4: [2, 1, 4], 5: [2, 5], 6: [2, 1, 0, 3, 6], 7: [2, 1, 4, 7], 8: [2, 5, 8]}}
# {'host_id': 3, 'memory': 10, 'routing_table': {3: [3], 0: [3, 0], 1: [3, 0, 1], 6: [3, 6], 4: [3, 4], 2: [3, 0, 1, 2], 7: [3, 6, 7], 5: [3, 4, 5], 8: [3, 6, 7, 8]}}
# {'host_id': 4, 'memory': 10, 'routing_table': {4: [4], 1: [4, 1], 0: [4, 1, 0], 3: [4, 3], 2: [4, 1, 2], 6: [4, 3, 6], 7: [4, 7], 5: [4, 5], 8: [4, 7, 8]}}
# {'host_id': 5, 'memory': 10, 'routing_table': {5: [5], 2: [5, 2], 1: [5, 2, 1], 0: [5, 2, 1, 0], 3: [5, 4, 3], 4: [5, 4], 6: [5, 4, 3, 6], 7: [5, 4, 7], 8: [5, 8]}}
# {'host_id': 6, 'memory': 10, 'routing_table': {6: [6], 3: [6, 3], 0: [6, 3, 0], 1: [6, 3, 0, 1], 4: [6, 3, 4], 7: [6, 7], 2: [6, 3, 0, 1, 2], 5: [6, 3, 4, 5], 8: [6, 7, 8]}}
# {'host_id': 7, 'memory': 10, 'routing_table': {7: [7], 4: [7, 4], 1: [7, 4, 1], 0: [7, 4, 1, 0], 3: [7, 4, 3], 2: [7, 4, 1, 2], 6: [7, 6], 5: [7, 4, 5], 8: [7, 8]}}
# {'host_id': 8, 'memory': 10, 'routing_table': {8: [8], 5: [8, 5], 2: [8, 5, 2], 1: [8, 5, 2, 1], 0: [8, 5, 2, 1, 0], 3: [8, 5, 4, 3], 4: [8, 5, 4], 6: [8, 7, 6], 7: [8, 7]}}
